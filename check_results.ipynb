# %% [markdown]
# SMALL DATASETS

# %%
import os

# %%
def check_ground_truth_status(dataset_name):
    root = "package_metadata/openml"
    target_path = os.path.join(root, dataset_name, "ground_truth")

    conditions = [
        ("SHAP Kernel ANN",    ["shap_", "kernel_", "ann"]),
        ("SAGE Perm ANN",      ["sage_", "permutation_", "ann"]),
        ("SHAP Kernel XGB",    ["shap_", "kernel_", "xgboost"]),
        ("SAGE Perm XGB",      ["sage_", "permutation_", "xgboost"]),
        ("SHAPIQ Kernel ANN",  ["shapiq_", "kernel_", "ann"]),
        ("SHAPIQ Kernel XGB",  ["shapiq_", "kernel_", "xgboost"]),
    ]

    if os.path.exists(target_path):
        files = [f.lower() for f in os.listdir(target_path)]
    else:
        files = []

    print(f"📊 check ground_truth for: {dataset_name}")
    print("-" * 30)

    results = []

    for label, keywords in conditions:
        is_found = False

        for fname in files:
            if all(word in fname for word in keywords):
                is_found = True
                break

        icon = "✅" if is_found else "❌"
        print(f"{icon} {label}")
        results.append(is_found)

    print("-" * 30 + "\n")
    return results

# %%
def check_kernels_iid_status(dataset_name):
    root = "package_metadata/openml"
    target_path = os.path.join(root, dataset_name, "kernels_iid_comparison")

    conditions = [
        ("SHAP Kernel ANN",    ["shap_", "kernel_", "ann"]),
        ("SAGE Perm ANN",      ["sage_", "permutation_", "ann"]),
        ("SHAP Kernel XGB",    ["shap_", "kernel_", "xgboost"]),
        ("SAGE Perm XGB",      ["sage_", "permutation_", "xgboost"]),
        ("SHAPIQ Kernel ANN",  ["shapiq_", "kernel_", "ann"]),
        ("SHAPIQ Kernel XGB",  ["shapiq_", "kernel_", "xgboost"]),
    ]

    if os.path.exists(target_path):
        files = [f.lower() for f in os.listdir(target_path)]
    else:
        files = []

    print(f"📉 check kernels_iid_comparison for: {dataset_name}")
    print("-" * 35)

    results = []

    for label, keywords in conditions:
        is_found = False

        for fname in files:
            if all(word in fname for word in keywords):
                is_found = True
                break

        icon = "✅" if is_found else "❌"
        print(f"{icon} {label}")
        results.append(is_found)

    print("-" * 35 + "\n")
    return results

# %%
def check_stein_thinning_status(dataset_name):
    root_dir = "package_metadata/openml"
    target_subfolder = "other_baselines"

    conditions = [
        ("ST SHAP ANN",     ["shap", "kernel", "ann", "stein_thinning"]),
        ("ST SAGE ANN",     ["sage", "permutation", "ann", "stein_thinning"]),
        ("ST SHAP XGB",     ["shap", "kernel", "xgboost", "stein_thinning"]),
        ("ST SAGE XGB",     ["sage", "permutation", "xgboost", "stein_thinning"]),
        ("ST SHAPIQ ANN",   ["shapiq", "kernel", "ann", "stein_thinning"]),
        ("ST SHAPIQ XGB",   ["shapiq", "kernel", "xgboost", "stein_thinning"]),
    ]

    target_path = os.path.join(root_dir, dataset_name, target_subfolder)

    if os.path.exists(target_path):
        files = [f.lower() for f in os.listdir(target_path)]
    else:
        files = []

    print(f"Dataset: {dataset_name}")
    print("-" * 30)

    for label, keywords in conditions:
        is_found = False
        for fname in files:
            if all(word in fname for word in keywords):
                is_found = True
                break

        icon = "✅" if is_found else "❌"
        print(f"{icon} {label}")

    print("-" * 30 + "\n")

# %%
def check_arfpy_status(dataset_name):
    root_dir = "package_metadata/openml"
    target_subfolder = "other_baselines"

    conditions = [
        ("A SHAP ANN",     ["shap", "kernel", "ann", "arfpy"]),
        ("A SAGE ANN",     ["sage", "permutation", "ann", "arfpy"]),
        ("A SHAP XGB",     ["shap", "kernel", "xgboost", "arfpy"]),
        ("A SAGE XGB",     ["sage", "permutation", "xgboost", "arfpy"]),
        ("A SHAPIQ ANN",   ["shapiq", "kernel", "ann", "arfpy"]),
        ("A SHAPIQ XGB",   ["shapiq", "kernel", "xgboost", "arfpy"]),
    ]

    target_path = os.path.join(root_dir, dataset_name, target_subfolder)

    if os.path.exists(target_path):
        files = [f.lower() for f in os.listdir(target_path)]
    else:
        files = []

    print(f"Dataset: {dataset_name}")
    print("-" * 30)

    for label, keywords in conditions:
        is_found = False
        for fname in files:
            if all(word in fname for word in keywords):
                is_found = True
                break

        icon = "✅" if is_found else "❌"
        print(f"{icon} {label}")

    print("-" * 30 + "\n")

# %%
def check_kernel_thinning_predictions_status(dataset_name):
    root_dir = "package_metadata/openml"
    target_subfolder = "other_baselines"

    conditions = [
        ("KT P SHAP ANN",     ["shap", "kernel", "ann", "kernel_thinning", "predictions"]),
        ("KT P SAGE ANN",     ["sage", "permutation", "ann", "kernel_thinning", "predictions"]),
        ("KT P SHAP XGB",     ["shap", "kernel", "xgboost", "kernel_thinning", "predictions"]),
        ("KT P SAGE XGB",     ["sage", "permutation", "xgboost", "kernel_thinning", "predictions"]),
        ("KT P SHAPIQ ANN",   ["shapiq", "kernel", "ann", "kernel_thinning", "predictions"]),
        ("KT P SHAPIQ XGB",   ["shapiq", "kernel", "xgboost", "kernel_thinning", "predictions"]),
    ]

    target_path = os.path.join(root_dir, dataset_name, target_subfolder)

    if os.path.exists(target_path):
        files = [f.lower() for f in os.listdir(target_path)]
    else:
        files = []

    print(f"Dataset: {dataset_name}")
    print("-" * 30)

    for label, keywords in conditions:
        is_found = False
        for fname in files:
            if all(word in fname for word in keywords):
                is_found = True
                break

        icon = "✅" if is_found else "❌"
        print(f"{icon} {label}")

    print("-" * 30 + "\n")

# %%
def check_kernel_thinning_stratified_status(dataset_name):
    root_dir = "package_metadata/openml"
    target_subfolder = "other_baselines"

    conditions = [
        ("KT STR SHAP ANN",     ["shap", "kernel", "ann", "kernel_thinning", "stratified"]),
        ("KT STR SAGE ANN",     ["sage", "permutation", "ann", "kernel_thinning", "stratified"]),
        ("KT STR SHAP XGB",     ["shap", "kernel", "xgboost", "kernel_thinning", "stratified"]),
        ("KT STR SAGE XGB",     ["sage", "permutation", "xgboost", "kernel_thinning", "stratified"]),
        ("KT STR SHAPIQ ANN",   ["shapiq", "kernel", "ann", "kernel_thinning", "stratified"]),
        ("KT STR SHAPIQ XGB",   ["shapiq", "kernel", "xgboost", "kernel_thinning", "stratified"]),
    ]

    target_path = os.path.join(root_dir, dataset_name, target_subfolder)

    if os.path.exists(target_path):
        files = [f.lower() for f in os.listdir(target_path)]
    else:
        files = []

    print(f"Dataset: {dataset_name}")
    print("-" * 30)

    for label, keywords in conditions:
        is_found = False
        for fname in files:
            if all(word in fname for word in keywords):
                is_found = True
                break

        icon = "✅" if is_found else "❌"
        print(f"{icon} {label}")

    print("-" * 30 + "\n")

# %%
def check_influence_status(dataset_name):
    root_dir = "package_metadata/openml"
    target_subfolder = "other_baselines"

    conditions = [
        ("INFLUENCE SHAP ANN",     ["shap", "kernel", "ann", "influence"]),
        ("INFLUENCE SAGE ANN",     ["sage", "permutation", "ann", "influence"]),
        ("INFLUENCE SHAPIQ ANN",   ["shapiq", "kernel", "ann", "influence"]),
    ]

    target_path = os.path.join(root_dir, dataset_name, target_subfolder)

    if os.path.exists(target_path):
        files = [f.lower() for f in os.listdir(target_path)]
    else:
        files = []

    print(f"Dataset: {dataset_name}")
    print("-" * 30)

    for label, keywords in conditions:
        is_found = False
        for fname in files:
            if all(word in fname for word in keywords):
                is_found = True
                break

        icon = "✅" if is_found else "❌"
        print(f"{icon} {label}")

    print("-" * 30 + "\n")

# %%
dataset_name = "video_transcoding"

# %%
check_ground_truth_status(dataset_name)
# Out:
# 📊 check ground_truth for: video_transcoding
# ------------------------------
# ✅ SHAP Kernel ANN
# ✅ SAGE Perm ANN
# ✅ SHAP Kernel XGB
# ✅ SAGE Perm XGB
# ✅ SHAPIQ Kernel ANN
# ✅ SHAPIQ Kernel XGB
# ------------------------------
# [True, True, True, True, True, True]

# %%
check_kernels_iid_status(dataset_name)
# Out:
# 📉 check kernels_iid_comparison for: video_transcoding
# -----------------------------------
# ✅ SHAP Kernel ANN
# ✅ SAGE Perm ANN
# ✅ SHAP Kernel XGB
# ✅ SAGE Perm XGB
# ❌ SHAPIQ Kernel ANN
# ❌ SHAPIQ Kernel XGB
# -----------------------------------
# [True, True, True, True, False, False]

# %%
check_stein_thinning_status(dataset_name)
# Out:
# Dataset: video_transcoding
# ------------------------------
# ✅ ST SHAP ANN
# ✅ ST SAGE ANN
# ✅ ST SHAP XGB
# ✅ ST SAGE XGB
# ❌ ST SHAPIQ ANN
# ❌ ST SHAPIQ XGB
# ------------------------------

# %%
check_arfpy_status(dataset_name)
# Out:
# Dataset: video_transcoding
# ------------------------------
# ✅ A SHAP ANN
# ✅ A SAGE ANN
# ✅ A SHAP XGB
# ✅ A SAGE XGB
# ✅ A SHAPIQ ANN
# ✅ A SHAPIQ XGB
# ------------------------------

# %%
check_influence_status(dataset_name)
# Out:
# Dataset: video_transcoding
# ------------------------------
# ❌ INFLUENCE SHAP ANN
# ❌ INFLUENCE SAGE ANN
# ❌ INFLUENCE SHAPIQ ANN
# ------------------------------

# %%
check_kernel_thinning_predictions_status(dataset_name)
# Out:
# Dataset: video_transcoding
# ------------------------------
# ✅ KT P SHAP ANN
# ✅ KT P SAGE ANN
# ✅ KT P SHAP XGB
# ✅ KT P SAGE XGB
# ✅ KT P SHAPIQ ANN
# ✅ KT P SHAPIQ XGB
# ------------------------------

# %%
check_kernel_thinning_stratified_status(dataset_name)
# Out:
# Dataset: video_transcoding
# ------------------------------
# ❌ KT STR SHAP ANN
# ❌ KT STR SAGE ANN
# ❌ KT STR SHAP XGB
# ❌ KT STR SAGE XGB
# ❌ KT STR SHAPIQ ANN
# ❌ KT STR SHAPIQ XGB
# ------------------------------

# %% [markdown]
# LARGE

# %%
def check_ground_truth_status(dataset_name):
    root = "package_metadata/openml"
    target_path = os.path.join(root, dataset_name, "ground_truth")

    conditions = [
        ("Expected gradients ANN",    ["expected_gradients", "ann"]),
    ]

    if os.path.exists(target_path):
        files = [f.lower() for f in os.listdir(target_path)]
    else:
        files = []

    print(f"📊 check ground_truth for: {dataset_name}")
    print("-" * 30)

    results = []

    for label, keywords in conditions:
        is_found = False

        for fname in files:
            if all(word in fname for word in keywords):
                is_found = True
                break

        icon = "✅" if is_found else "❌"
        print(f"{icon} {label}")
        results.append(is_found)

    print("-" * 30 + "\n")
    return results

# %%
def check_kernels_iid_status(dataset_name):
    root = "package_metadata/openml"
    target_path = os.path.join(root, dataset_name, "kernels_iid_comparison")

    conditions = [
        ("KERNELS EXP_GRAD ANN", ["expected_gradients", "ann"]),
    ]

    if os.path.exists(target_path):
        files = [f.lower() for f in os.listdir(target_path)]
    else:
        files = []

    print(f"📉 check kernels_iid_comparison for: {dataset_name}")
    print("-" * 35)

    results = []

    for label, keywords in conditions:
        is_found = False

        for fname in files:
            if all(word in fname for word in keywords):
                is_found = True
                break

        icon = "✅" if is_found else "❌"
        print(f"{icon} {label}")
        results.append(is_found)

    print("-" * 35 + "\n")
    return results

# %%
def check_stein_thinning_status(dataset_name):
    root_dir = "package_metadata/openml"
    target_subfolder = "other_baselines"

    conditions = [
        ("ST EXP_GRAD ANN",     ["expected_gradients", "ann", "stein_thinning"]),
    ]

    target_path = os.path.join(root_dir, dataset_name, target_subfolder)

    if os.path.exists(target_path):
        files = [f.lower() for f in os.listdir(target_path)]
    else:
        files = []

    print(f"Dataset: {dataset_name}")
    print("-" * 30)

    for label, keywords in conditions:
        is_found = False
        for fname in files:
            if all(word in fname for word in keywords):
                is_found = True
                break

        icon = "✅" if is_found else "❌"
        print(f"{icon} {label}")

    print("-" * 30 + "\n")

# %%
def check_arfpy_status(dataset_name):
    root_dir = "package_metadata/openml"
    target_subfolder = "other_baselines"

    conditions = [
        ("A EXP_GRAD ANN",     ["expected_gradients", "ann", "arfpy"]),
    ]

    target_path = os.path.join(root_dir, dataset_name, target_subfolder)

    if os.path.exists(target_path):
        files = [f.lower() for f in os.listdir(target_path)]
    else:
        files = []

    print(f"Dataset: {dataset_name}")
    print("-" * 30)

    for label, keywords in conditions:
        is_found = False
        for fname in files:
            if all(word in fname for word in keywords):
                is_found = True
                break

        icon = "✅" if is_found else "❌"
        print(f"{icon} {label}")

    print("-" * 30 + "\n")

# %%
def check_kernel_thinning_predictions_status(dataset_name):
    root_dir = "package_metadata/openml"
    target_subfolder = "other_baselines"

    conditions = [
        ("P EXP_GRAD SHAP ANN",     ["expected_gradients", "ann", "kernel_thinning", "predictions"]),
    ]

    target_path = os.path.join(root_dir, dataset_name, target_subfolder)

    if os.path.exists(target_path):
        files = [f.lower() for f in os.listdir(target_path)]
    else:
        files = []

    print(f"Dataset: {dataset_name}")
    print("-" * 30)

    for label, keywords in conditions:
        is_found = False
        for fname in files:
            if all(word in fname for word in keywords):
                is_found = True
                break

        icon = "✅" if is_found else "❌"
        print(f"{icon} {label}")

    print("-" * 30 + "\n")

# %%
def check_kernel_thinning_stratified_status(dataset_name):
    root_dir = "package_metadata/openml"
    target_subfolder = "other_baselines"

    conditions = [
        ("STR EXP_GRAD ANN", ["expected_gradients", "ann", "kernel_thinning", "stratified"]),
    ]

    target_path = os.path.join(root_dir, dataset_name, target_subfolder)

    if os.path.exists(target_path):
        files = [f.lower() for f in os.listdir(target_path)]
    else:
        files = []

    print(f"Dataset: {dataset_name}")
    print("-" * 30)

    for label, keywords in conditions:
        is_found = False
        for fname in files:
            if all(word in fname for word in keywords):
                is_found = True
                break

        icon = "✅" if is_found else "❌"
        print(f"{icon} {label}")

    print("-" * 30 + "\n")

# %%
def check_influence_status(dataset_name):
    root_dir = "package_metadata/openml"
    target_subfolder = "other_baselines"

    conditions = [
        ("INFLUENCE EXP_GRAD ANN", ["expected_gradients", "ann", "influence"]),
    ]

    target_path = os.path.join(root_dir, dataset_name, target_subfolder)

    if os.path.exists(target_path):
        files = [f.lower() for f in os.listdir(target_path)]
    else:
        files = []

    print(f"Dataset: {dataset_name}")
    print("-" * 30)

    for label, keywords in conditions:
        is_found = False
        for fname in files:
            if all(word in fname for word in keywords):
                is_found = True
                break

        icon = "✅" if is_found else "❌"
        print(f"{icon} {label}")

    print("-" * 30 + "\n")

# %%
dataset_name = "connect-4"

# %%
check_ground_truth_status(dataset_name)
# Out:
# 📊 check ground_truth for: connect-4
# ------------------------------
# ✅ Expected gradients ANN
# ------------------------------
# [True]

# %%
check_kernels_iid_status(dataset_name)
# Out:
# 📉 check kernels_iid_comparison for: connect-4
# -----------------------------------
# ✅ KERNELS EXP_GRAD ANN
# -----------------------------------
# [True]

# %%
check_stein_thinning_status(dataset_name)
# Out:
# Dataset: connect-4
# ------------------------------
# ✅ ST EXP_GRAD ANN
# ------------------------------

# %%
check_arfpy_status(dataset_name)
# Out:
# Dataset: connect-4
# ------------------------------
# ✅ A EXP_GRAD ANN
# ------------------------------

# %%
check_kernel_thinning_predictions_status(dataset_name)
# Out:
# Dataset: connect-4
# ------------------------------
# ✅ P EXP_GRAD SHAP ANN
# ------------------------------

# %%
check_kernel_thinning_stratified_status(dataset_name)
# Out:
# Dataset: connect-4
# ------------------------------
# ❌ STR EXP_GRAD ANN
# ------------------------------
