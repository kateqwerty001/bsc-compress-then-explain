# %% [markdown]
# needed prep:
# - Handle missing values
# - Encode categorical feature
# - Scale numeric features
# - Drop duplicate rows
# - Drop constant columns
# - Drop ID-like columns

# %%
# %pip install openml
# Out:
# Requirement already satisfied: openml in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (0.15.1)
# Requirement already satisfied: liac-arff>=2.4.0 in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from openml) (2.5.0)
# Requirement already satisfied: xmltodict in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from openml) (0.14.2)
# Requirement already satisfied: requests in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from openml) (2.32.3)
# Requirement already satisfied: scikit-learn>=0.18 in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from openml) (1.6.1)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from openml) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.0.0 in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from openml) (2.2.3)
# Requirement already satisfied: scipy>=0.13.3 in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from openml) (1.15.2)
# Requirement already satisfied: numpy>=1.6.2 in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from openml) (1.26.4)
# Requirement already satisfied: minio in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from openml) (7.2.15)
# Requirement already satisfied: pyarrow in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from openml) (19.0.1)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from openml) (4.67.1)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from openml) (24.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from pandas>=1.0.0->openml) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from pandas>=1.0.0->openml) (2025.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from python-dateutil->openml) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from scikit-learn>=0.18->openml) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from scikit-learn>=0.18->openml) (3.5.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from minio->openml) (2025.1.31)
# Requirement already satisfied: urllib3 in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from minio->openml) (2.3.0)
# Requirement already satisfied: argon2-cffi in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from minio->openml) (23.1.0)
# Requirement already satisfied: pycryptodome in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from minio->openml) (3.21.0)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from minio->openml) (4.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from requests->openml) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from requests->openml) (3.10)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from argon2-cffi->minio->openml) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->minio->openml) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/cte/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio->openml) (2.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import os
# In python file use __file__ , not notebook's directory 
notebook_dir = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(notebook_dir, '..', 'custom_packages', 'bonXAI-main')))

# %%
import openml
import pandas as pd
from bonXAI.core.tabularPreprocessor import TabularPreprocessor

# Load from OpenML ID 1461 (task 7592)
d = openml.datasets.get_dataset("bank-marketing", version=1)
X, y, cat_mask, attr_names = d.get_data(target=d.default_target_attribute)
X = pd.DataFrame(X, columns=attr_names[:-1])
y = pd.Series(y, name=d.default_target_attribute)
df = pd.concat([X, y], axis=1)

# add id like column to test
df["id_like"] = range(len(df))

# add a duplicate to test cleaner
df = pd.concat([df, df.iloc[[0]]], ignore_index=True)

X, y = df.drop(columns=[d.default_target_attribute]), df[d.default_target_attribute]

# fit + transform on the whole set
prep = TabularPreprocessor(
    task_type="classification",
    id_like_threshold=0.99,
    scale_all_numeric_after_encoding=True,
    scale_target_in_regression=False,
    random_state=0,
)
X_clean, y_enc = prep.fit_transform(X, y)

print("Original shape:", X.shape)
print("Processed shape:", X_clean.shape)
print("Task type:", prep.get_report().task_type)
print("Dropped constant:", prep.get_report().dropped_constant)
print("Dropped ID-like:", prep.get_report().dropped_id_like)
# Out:
# Original shape: (45212, 16)
# Processed shape: (45211, 15)
# Task type: classification
# Dropped constant: []
# Dropped ID-like: ['id_like']

# %%
print(prep.get_report())
print(y_enc)
X_clean.head(5)
# Out:
# PreprocessReport(dropped_constant=[], dropped_id_like=['id_like'], kept_raw_columns=['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15'], numeric_columns=['V1', 'V6', 'V10', 'V12', 'V13', 'V14', 'V15'], categorical_columns=['V2', 'V3', 'V4', 'V5', 'V7', 'V8', 'V9', 'V11'], task_type='classification')
# [0 0 0 ... 1 0 0]
#          V1        V6       V10       V12       V13       V14      V15  \
# 0  1.606965  0.256419 -1.298476  0.011016 -0.569351 -0.411453 -0.25194
# 1  0.288529 -0.437895 -1.298476 -0.416127 -0.569351 -0.411453 -0.25194
# 2 -0.747384 -0.446762 -1.298476 -0.707361 -0.569351 -0.411453 -0.25194
# 3  0.571051  0.047205 -1.298476 -0.645231 -0.569351 -0.411453 -0.25194
# 4 -0.747384 -0.447091 -1.298476 -0.233620 -0.569351 -0.411453 -0.25194
#
#          V2        V3        V4        V5        V7        V8        V9  \
# 0  0.469902 -0.742737  1.414845  0.134607 -0.893869  0.436681 -1.567215
# 1 -0.146395  1.532768 -0.487163  0.134607 -0.893869  0.436681 -1.567215
# 2 -0.782215 -0.742737 -0.487163  0.134607 -0.893869 -2.288825 -1.567215
# 3 -1.010193 -0.742737  0.800197  0.134607 -0.893869  0.436681 -1.567215
# 4  0.024478  1.532768  0.800197  0.134607  1.118484  0.436681 -1.567215
#
#         V11
# 0 -0.596999
# 1 -0.596999
# 2 -0.596999
# 3 -0.596999
# 4 -0.596999

# %%
# Load from OpenML ID 1491 (task 31)
d = openml.datasets.get_dataset("one-hundred-plants-margin", version=1)
X, y, cat_mask, attr_names = d.get_data(target=d.default_target_attribute)
X = pd.DataFrame(X, columns=attr_names[:-1])
y = pd.Series(y, name=d.default_target_attribute)
df = pd.concat([X, y], axis=1)

# add id like column to test
df["id_like"] = range(len(df))

# add a duplicate to test cleaner
df = pd.concat([df, df.iloc[[0]]], ignore_index=True)

X, y = df.drop(columns=[d.default_target_attribute]), df[d.default_target_attribute]

# fit + transform on the whole set
prep = TabularPreprocessor(
    task_type="classification",
    id_like_threshold=0.99,
    scale_all_numeric_after_encoding=True,
    scale_target_in_regression=False,
    random_state=0,
)
X_clean, y_enc = prep.fit_transform(X, y)

print("Original shape:", X.shape)
print("Processed shape:", X_clean.shape)
print("Task type:", prep.get_report().task_type)
print("Dropped constant:", prep.get_report().dropped_constant)
print("Dropped ID-like:", prep.get_report().dropped_id_like)

prep.get_report()
# Out:
# Original shape: (1601, 64)
# Processed shape: (1600, 63)
# Task type: classification
# Dropped constant: []
# Dropped ID-like: ['id_like']
# PreprocessReport(dropped_constant=[], dropped_id_like=['id_like'], kept_raw_columns=['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'V29', 'V30', 'V31', 'V32', 'V33', 'V34', 'V35', 'V36', 'V37', 'V38', 'V39', 'V40', 'V41', 'V42', 'V43', 'V44', 'V45', 'V46', 'V47', 'V48', 'V49', 'V50', 'V51', 'V52', 'V53', 'V54', 'V55', 'V56', 'V57', 'V58', 'V59', 'V60', 'V61', 'V62', 'V63'], numeric_columns=['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'V29', 'V30', 'V31', 'V32', 'V33', 'V34', 'V35', 'V36', 'V37', 'V38', 'V39', 'V40', 'V41', 'V42', 'V43', 'V44', 'V45', 'V46', 'V47', 'V48', 'V49', 'V50', 'V51', 'V52', 'V53', 'V54', 'V55', 'V56', 'V57', 'V58', 'V59', 'V60', 'V61', 'V62', 'V63'], categorical_columns=[], task_type='classification')

# %%
# Load from OpenML ID 204 (task 2295)
d = openml.datasets.get_dataset("cholesterol", version=1)
X, y, cat_mask, attr_names = d.get_data(target=d.default_target_attribute)
X = pd.DataFrame(X, columns=attr_names[:-1])
y = pd.Series(y, name=d.default_target_attribute)
df = pd.concat([X, y], axis=1)

# add id like column to test
df["id_like"] = range(len(df))

# add a duplicate to test cleaner
df = pd.concat([df, df.iloc[[0]]], ignore_index=True)

X, y = df.drop(columns=[d.default_target_attribute]), df[d.default_target_attribute]

# fit + transform on the whole set
prep = TabularPreprocessor(
    task_type="regression",
    id_like_threshold=0.99,
    scale_all_numeric_after_encoding=True,
    scale_target_in_regression=False,
    random_state=0,
)
X_clean, y_enc = prep.fit_transform(X, y)

print("Original shape:", X.shape)
print("Processed shape:", X_clean.shape)
print("Task type:", prep.get_report().task_type)
print("Dropped constant:", prep.get_report().dropped_constant)
print("Dropped ID-like:", prep.get_report().dropped_id_like)

prep.get_report()
# Out:
# Original shape: (304, 13)
# Processed shape: (303, 12)
# Task type: regression
# Dropped constant: []
# Dropped ID-like: ['id_like']
# PreprocessReport(dropped_constant=[], dropped_id_like=['id_like'], kept_raw_columns=['age', 'sex', 'cp', 'trestbps', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal'], numeric_columns=['age', 'trestbps', 'thalach', 'oldpeak', 'ca'], categorical_columns=['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'thal'], task_type='regression')
